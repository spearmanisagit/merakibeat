# %% [markdown]
# <a href="https://colab.research.google.com/github/spearmanisagit/merakibeat/blob/master/Copy_of_Share_API_Workbook_Revised_v01_3_231010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Meraki Automation using Python**
#
#
# **Disclaimer**
#
# This training document is to familiarize with writing automation on the Meraki Dashboard using Python. Although the lab design and configuration examples could be used as a reference, it’s not a real design, thus not all recommended features are used, or enabled optimally. For the design related questions please contact your representative at Cisco, or a Cisco partner.

# %% [markdown]
# # **Setup**

# %% [markdown]
# ## **Copy this workbook**
# Start by creating a copy of the workbook.
#
# **Note:** you need a google account.
#
# **Note:** do not use incognito browsing.
#
# ![Screenshot 2022-11-03 at 3.05.27 pm.png](data:image/png;base64,...)

# %% [markdown]
# ## **How to use google Colab**
# 1. Select the code
# 2. use CTRL/command +C to copy
# 3. select the destination block
# 4. use CTRL/command +V to paste
# 5. use the Play button &#9654; to run the code
#
# **Test it in the next section**

# %% [markdown]
# ##**Hello world!**
# Test a basic line of code to get familiar with the google colab interface
#
# **Copy (CTRL+C or Command+C) and paste (CTRL+V or Command+V) the following code in the block below, when ready use the play button &#9654; to run the code**
#
# ```python
# print('Hello World!')
# ```
# **Note:** the first execution might take some time due to environment initialization

# %% [markdown]
# # **Install the Meraki Python library**
# Install the Meraki Python library.
#
# **Copy and paste the following code in the block below, when ready use the play button to run your code**
#
#
# ```bash
# pip install meraki
# ```
# **Note:** the first execution might take some time due to environment initialization
#
# **Note:** if the environment gets disconnect the libraries must be installed again

# %% [markdown]
# # **First API call**
# 1. Get organizations
#
# 2. Print organizations
#
# 3. Print the data type of the response

# %% [markdown]
# ## **Get Organizations**
# Copy the Meraki Python Library GET request for organizations from the API docs and paste it into the code block below.
#
# [GET Organizations Request](https://developer.cisco.com/meraki/api-v1/#!get-organizations)
#
# ![Screenshot 2022-11-01 at 9.34.02 pm.png](data:image/png;base64,...)

# %% [markdown]
# This code already contains a read only API KEY available for testing.
#
# The following code will request a list of all the organizations accessible with the specified API_KEY
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
# # Instead, use an environment variable as shown under the Usage section
# # @ https://github.com/meraki/dashboard-api-python/
#
# dashboard = meraki.DashboardAPI(API_KEY)
#
# response = dashboard.organizations.getOrganizations()
# ```

# %% [markdown]
# ##**Print Organizations**
# Response contains the list of all the organization accessible with the given API key
#
# Print the content of **response**
# ```python
# print(response)
# ```

# %% [markdown]
# ## **Print response type**
# The variable **response** contains the information returned from the API call
#
# Check the data type of the **response**.
#
# ```python
# print(type(response))
# ```

# %% [markdown]
# **response** is a list, different data type allows different operations.

# %% [markdown]
# #**Python Basics**
# Before going any further, review some basic python concepts.

# %% [markdown]
# ## **Comments**
#
# A line that starts with # is a comment
# ```python
# # this is a comment not a line of executable code
# print('This is executed code')
# ```

# %% [markdown]
# Comments are useful to make code easier to understand and share.

# %% [markdown]
# ## **Data Types**
# **List** is one of the data types encountered in a previous example.
#
# Other data types to remember when using the Meraki Python library are:
#
# **Integer**
#
# An int is an interger number
#
# ```python
# # an interger, <class int>
# # store an integer in a variable
# variable=3
# # print the value
# print(variable)
# # print the type
# print(type(variable))
# ```

# %% [markdown]
# **String**
#
# A string is text contained between single quotes (or double quotes)
#
# 'this is a string'
#
# ```python
# # a string, <class 'str'>
# # store a string in a variable
# variable='I am a string'
# # print the value
# print(variable)
# # print the type
# print(type(variable))
# ```

# %% [markdown]
# **Question:** what's the type of *variable* in this case?
# ```python
# variable='3'
# print(variable)
# print(type(variable))
# ```
# Test the code to see the answer.

# %% [markdown]
# ## **String concatenation**
#
# Strings and other variables can be concatenated to produce console output that are easier to read.
#
# **Hint:** to get familiar with the code editing, change the value of **my_name**.
#
# ```python
# my_name = 'change my value'
#
# # concatenate a text to a variable
# print ('My name is ' , my_name)
# ```

# %% [markdown]
# ## **Lists and Dictionaries**
# **Strings, List** and **Dictionaries** are the most used data type when working with Meraki API
#
#
# *   **List** are used to store multiple rows of similar items (e.g.: all organizations, all the networks in an organization)
# * **List** use square brackets as a delimiter [ ] and commas , as a separator
#
# ```python
# # my list
# my_list=['network 0','network 1','network 2']
# # print the full list
# print (my_list)
# # print the type
# print(type(my_list))
# ```

# %% [markdown]
# *   **Dictionaries** are collection of key, value pair related to the same item
# * **Dictionaries** use curly brackets as a delimiter { } colon : between the key and the value and commas , as a separator
#
# ```python
# # my dictionary
# my_dict={'name':'home network','status':'ok'}
# # print the full dictionary
# print (my_dict)
# # print the value associated to the key 'name'
# print (my_dict['name'])
# # print a sentence using string concatenation
# print ('The network status is', my_dict['status'])
# # print the type
# print(type(my_dict))
# ```

# %% [markdown]
# ## **Example**
# Print the response from the first example and notice how **list**, **dictionaries** and **string** appear in output.
#
# ```python
# #print the reposnse
# print(response)
#
# #print the type of response
# print(type(response)
# ```

# %% [markdown]
# # **Tabulations**
# Python use tabulations (tab) to define what's inside a block.
#
# A block begin with colon :
#
# ```python
# print ('Outside of the for loop - print once')
# for x in range(1,4):
#   print (' Inside the for loop - print', x ,'time')
# print ('Outside of the for loop - print once')
# ```

# %% [markdown]
# # **Loops and Filters**
#
# 1. **For** loop
# 2.   Attribute filter
# 3.  **If Else** statements
#
#
# The first API call was working but readability can be improved.
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# dashboard = meraki.DashboardAPI(API_KEY)
#
# response = dashboard.organizations.getOrganizations()
#
# print(response)
# ```

# %% [markdown]
# ## **For loop**
# Because **response** is a list it can be processed using a **for** loop.
#
# In a for loop each entry of a list can be analyzed as single item.
#
# ```python
# #for each oraganization in reposnse extract each element of the list on the variable org
# for org in response:
#   #print each org
#   print(org)
# ```

# %% [markdown]
# ## **Filters**
# The previous output is more organized but still display to much information.
#
# Reduce the output to 2 fields for each organization: **id** and **name**
#
# Each **org** is a dictionary, use the correct key to print the associated value.
#
# Use string concatenation for a better looking output
# ```python
# for org in response:
#   print('Org ID: ', org['id'], 'Org Name: ', org['name'])
# ```
# **Try:** print out different fields from the org like 'url' or 'api'

# %% [markdown]
# ## **If**
# Using **if**, we can filter the list of orgs for a particular item.
#
#
# ```python
# for org in response:
#   if org['name'] == 'DevNetAssoc':
#     print('Org ID: ', org['id'], 'Org Name: ', org['name'])
# ```

# %% [markdown]
# ## **If Else**
# Using ***if..else***, we can filter the list of orgs for a particular item.
#
#
# ```python
# for org in response:
#   if org['name'] == 'DevNetAssoc':
#     print(org['id'])
#   else:
#     print('---')
# ```

# %% [markdown]
# #**Recap so far**
#
# In the code so far is performing the following actions:
#
#
# 1.   Import the meraki library
# 2.   Configure a valid API_KEY
# 3. Create a Dashboard variable to be used for api calls
# 4. Retrieve the list of all the organizations
# 5. Print all the organizations name and id with a for loop
# 6. Search a specific organization by name and print the organization ID
# 7. Save the Org ID in variable
#
#
# Try and identify those different actions in the code below
# ```python
# #import the meraki library
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# #create dashboard variable
# dashboard = meraki.DashboardAPI(API_KEY)
#
# #get the list of all the org
# response = dashboard.organizations.getOrganizations()
#
# # print all the org id and org name
# print ('\n=== Print all the org id and org name ===')
# for org in response:
#   print('Org ID: ', org['id'], 'Org Name: ', org['name'])
#
# # find the org ID of with the specified name
# print ('\n=== Find the org id ===')
# for org in response:
#   if org['name'] == 'DevNetAssoc':
#     #print the org id
#     print('Org ID: ',org['id'])
#     #save the org id to be used later
#     organization_id=org['id']
# ```

# %% [markdown]
# # **Script together - Print wireless devices statuses**

# %% [markdown]
# ## **Scenario**
# Write a script to print the serial number and the status of wireless devices in the **DevNetAssoc** organization.
#
# ![diagram - device status exercise.png](data:image/png;base64,...)

# %% [markdown]
# Use [Get Organization Devices Statuses](https://developer.cisco.com/meraki/api-latest/#!get-organization-devices-statuses) to retrive the list of devices.
#
# In the dictionary associated with a device
#
# **['serial']** = serial number
#
# **['status']** = status of the device
#
# **['productType']** = type of the device, 'wireless' is the string value identifying a wireless device

# %% [markdown]
# Let's start with a skeleton wihtout code.
#
# What needs to be done.
#
# ```python
# # 1 import libraries
#
# # 2 define variables
#
# # 3 create 'dashboard' object
#
# # 4 get the list of all organizations
#
# # 5 find the organization id of 'DevNetAssoc'
#
# # 6 get all the device status in the organization
#
# # 7 iterate on all the devices with a for loop and print wireless devices
#
# ```
#
# the code for steps 1 to 5 it's already done
#
# ```python
# # 1 import the meraki library
# import meraki
#
# # 2 Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # 3 create dashboard variable
# dashboard = meraki.DashboardAPI(API_KEY)
#
# # 4.1 get the list of all the org
# response = dashboard.organizations.getOrganizations()
#
# # 4.2 print all the org id and org name
# print ('\n=== Print all the org id and org name ===')
# for org in response:
#   print('Org ID: ', org['id'], 'Org Name: ', org['name'])
#
# # 5 find the org ID of with the specified name
# print ('\n=== Find the org id ===')
# for org in response:
#   if org['name'] == 'DevNetAssoc':
#     #print the org id
#     print('Org ID: ',org['id'])
# ```

# %% [markdown]
# ## **Possible Solution**
# For reference find a possible solution below

# %% [markdown]
# ```python
# # import the meraki library
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # create dashboard variable
# dashboard = meraki.DashboardAPI(API_KEY)
#
# # get the list of all the org
# response = dashboard.organizations.getOrganizations()
#
# # Find org id for DevNetAssoc
# print ('=== Find the org id for DevNetAssoc ===')
# for org in response:
#   if org['name'] == 'DevNetAssoc':
#     #print the org id
#     print('Org ID: ',org['id'])
#     #save the org id to be used later
#     organization_id=org['id']
#
# #find all the device status in the organization
# response_devices = dashboard.organizations.getOrganizationDevicesAvailabilities(
#     organization_id, total_pages='all')
#
# print('=== Print the status of the wireless devices ===')
# # iterate on all the devices with a for loop
# for device in response_devices:
#     # filter the device tipe to only print wireless devices
#     if device['productType'] == 'wireless':
#         # print device serial number and device status
#         print([device['serial'], device['status']])
#
# ```

# %% [markdown]
# # **Functions & Parameters**

# %% [markdown]
# ## **Parameters**
#
# Parameters can be used to change the behavior of a function, some parameters are mandatory some are optional
#
# **API_KEY** is an example of a required parameter when using the function that create **dashboard**
#
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # using function meraki.DashboardAPI passing the parameter API_KEY
# dashboard = meraki.DashboardAPI(API_KEY)
#
# # get organizations
# response = dashboard.organizations.getOrganizations()
#
# # print the response
# print(response)
#
# ```

# %% [markdown]
# **suppress_logging** is an example of an optional parameter when creating **dashboard**
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=True)
#
# # get organizations
# response = dashboard.organizations.getOrganizations()
#
# # print the response
# print(response)
#
# ```
# Run this code and compare the output between this and the previous one. Notice any differences?

# %% [markdown]
# **Using different parameters allow to change the code behavior, in this case disabling the on screen logging for each dashboard API call**

# %% [markdown]
# ## **Functions**
# A function is a “chunk” of code that can be used repeatedly, rather than writing it out multiple times.
#
# Functions are defined using keyword **def** followed by the function name and optional **parameters**
#
# Functions can return results to the main code using the keyword **return**
#
# Here an example of a function definition that given an organization name can return the organization id.
#
# ```python
# def get_org_id(org_name_to_find):
#   # code that perform actions in the function goes here
#   return something
# ```
#
# **Question:** can you identify the function in the code below?
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=True)
#
# # function given an org name return the org id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# print('Org id: ',org_id)
# ```
#
# Test the code

# %% [markdown]
# # **More Examples - Print Firewall rules**

# %% [markdown]
# ## **Scenario**
# Find an org id using the name, org name: **DevNetAssoc**
#
# Get all the network in the organization.
#
# **Hint:** use the [Get Organization Networks](https://developer.cisco.com/meraki/api-latest/#!get-organization-networks)
#
# For each network print the list of all layer 3 firewall rules one per line
#
# **Hint:** use the [Get Network Appliance Firewall L3 Firewall Rules](https://developer.cisco.com/meraki/api-latest/#!get-network-appliance-firewall-l-3-firewall-rules)
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=True)
#
# # given a name return the organization id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# #get networks id
#
# #for each network get firewall rules
#
# #print firewall rules
# ```

# %% [markdown]
# ## **Possible Solution**
#
# ```python
# import meraki
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=True)
#
# # given a name return the organization id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# #get all the network in the selected organization
# network_list = dashboard.organizations.getOrganizationNetworks(org_id, total_pages='all')
#
# #iterate over each network
# for network in network_list:
#
#   #print the name for clarity
#   print(network['name'])
#
#   #retrive all the L3 FW rules for each network
#   fw_rules = dashboard.appliance.getNetworkApplianceFirewallL3FirewallRules(network['id'])
#   # print(type(fw_rules))
#
#   # extract the list of the firewall rules
#   rules_list=fw_rules['rules']
#   # print(type(rules_list))
#
#   # iterate over rule element and print it
#   for rule in rules_list:
#      print(rule)
# ```

# %% [markdown]
# # **Advanced topics**
#
#
# *   Table output
# *   CSV Output
# * CSV Input

# %% [markdown]
# ## **Tables**
# Additional libraries can be used to obtain easier to read output.
#
# In the next example **prettytable** will be used.
#
# Install the library first.
#
# ```bash
# pip install prettytable
# ```

# %% [markdown]
# Try and run the code as an alternative to the last exercise to display the output in a table.
#
# ```python
# import meraki
# import prettytable
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # set a new variable to suppress logging
# disable_logging=True
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=disable_logging)
#
# # given a name return the organization id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# network_list = dashboard.organizations.getOrganizationNetworks(org_id, total_pages='all')
#
# for network in network_list:
#   print(network['name'])
#   response = dashboard.appliance.getNetworkApplianceFirewallL3FirewallRules(network['id'])
#   field_names = response['rules'][0].keys()
#   table = prettytable.PrettyTable()
#   table.field_names = field_names
#   for rule in response['rules']:
#           table.add_row(list(rule.values()))
#   print(table)
# ```

# %% [markdown]
# ## **CSV files as output**
# Comma-separated value (.csv) file can be used as an alternative to the console to store the output generated from the code.
#
# This example will store L3 FW rules in a separate .csv file for each network.
#
# Try and run the code as an alternative to the last exercise.
#
# ```python
# import meraki
# import csv
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # set a new variable to suppress logging
# disable_logging=True
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=disable_logging)
#
# # given a name return the organization id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# network_list = dashboard.organizations.getOrganizationNetworks(org_id, total_pages='all')
#
# for network in network_list:
#   print(network['name'])
#   response = dashboard.appliance.getNetworkApplianceFirewallL3FirewallRules(network['id'])
#   field_names = response['rules'][0].keys()
#   with open(network['name']+'.csv', 'w', newline='') as csvfile:
#     writer = csv.DictWriter(csvfile, fieldnames=field_names)
#     writer.writeheader()
#     for rule in response['rules']:
#       writer.writerow(rule)
#   print('CSV file created.')
# ```

# %% [markdown]
# Generated files can be found in the **File** tab 📁 on the right

# %% [markdown]
# ##**CSV files as input**
# Similar methods can be used to source information from a CSV file.
#
# Update the code using a file name generated in the previous exercise.
#
# **Hint:** the file name is case sensitive.
# ```python
# import csv
#
# #update this with a file name in your file list from the previous exercise
# with open('< yourfile name >.csv') as csv_file:
#     csv_reader = csv.DictReader(csv_file)
#     for row in csv_reader:
#         print (type(row))
#         print (row)
#         # uncomment the row below the demonstrate how to access row as a dictionary
#         #print ('=> Comment: ', row['comment'], ', Policy: ', row['policy'])
# ```

# %% [markdown]
# Use a csv file as a source to update all the L3 firewall rules for all the network of an org
#
# Update the code using a file name generated in the previous exercise.
#
# **Hint:** the file name is case sensitive.
#
# **This code will fail due to read only permission API KEY**
#
# ```python
# import csv
# import meraki
#
#
# # Defining your API key as a variable in source code is not recommended
# API_KEY = '6bec40cf957de430a6f1f2baa056b99a4fac9ea0'
#
# # define the org name do find
# org_name_to_find='DevNetAssoc'
#
# # define csv file to use as a source
# csv_file_name='< yourfile name >.csv'
#
# # set a new variable to suppress logging
# disable_logging=True
#
# # passing the API_KEY and the disabling the logging
# dashboard = meraki.DashboardAPI(API_KEY,suppress_logging=disable_logging)
#
# # given a name return the organization id
# def get_org_id(org_name_to_find):
#     response = dashboard.organizations.getOrganizations()
#     for org in response:
#         org_name = org['name']
#         if org_name == org_name_to_find:
#             org_id = org['id']
#     return org_id
#
# # call the function
# org_id = get_org_id(org_name_to_find)
#
# # create an empty list
# my_rules_list=[]
#
# # create a list with all the rules in the csv file
# with open(csv_file_name) as csv_file:
#     csv_reader = csv.DictReader(csv_file)
#     for row in csv_reader:
#       my_rules_list.append(row)
#
# #print(my_rules_list)
#
# #get all the networks
# network_list = dashboard.organizations.getOrganizationNetworks(org_id, total_pages='all')
#
# #for each network apply the same set of firewall rules obtained from the csv file
# for network in network_list:
#   #this call will fail with a 403 Forbidden
#   dashboard.appliance.updateNetworkApplianceFirewallL3FirewallRules(network['id'], rules=my_rules_list)
# ```

# %% [markdown]
# **End**

# %% [markdown]
# **Document parameters - do not modify**
#
# **Organization Name** = DevNetAssoc
#
# **Organization ID** = 3665367146726162441
#
# **API Key RO** = 6bec40cf957de430a6f1f2baa056b99a4fac9ea0
